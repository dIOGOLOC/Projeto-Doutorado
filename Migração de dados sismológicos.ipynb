# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import shapefile
import numpy as np

# %%
map = Basemap(llcrnrlon=-50,llcrnrlat=-10,urcrnrlon=-40.,urcrnrlat=-2,
             resolution='i', projection='tmerc', lat_0 = -6, lon_0 = -45)

# %%
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#ddaa66',lake_color='aqua')
map.drawcoastlines()

# %%
sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/section/profile/profiles')
shapes = sf.shapes()

# %%
len(shapes)
# Out:
# 8583

# %%
a = shapes[0]

# %%
a.shapeType
# Out:
# 1

# %%
data = np.genfromtxt('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/section/profile/section.csv',delimiter=',',skip_header=1)

# %%
X = data[:,0]
Y = data[:,1]
Z = data[:,5]

# %%
plt.plot(X,Z)
plt.savefig('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/Mapas/perfil1.svg')

# %%
# Out:
# array([ 182.,  180.,  180., ...,  283.,  297.,  310.])
